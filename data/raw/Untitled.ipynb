# %%
from sklearn.datasets import load_iris

data = load_iris()

# %%
import pandas as pd

df = pd.DataFrame(data.data, columns=data.feature_names)

# %%
df['target'] = data.target

# %%
train = pd.concat([X_train, y_train], axis=1)

# %%
train = pd.concat([X_train, y_train], axis=1)

# %%
import numpy as np

len(np.unique(train[['target']].values))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [26], in <cell line: 3>()
#       1 import numpy as np
# ----> 3 np.nunique(train[['target']].values)
#
# File ~/envs/abl/lib/python3.8/site-packages/numpy/__init__.py:315, in __getattr__(attr)
#     312     from .testing import Tester
#     313     return Tester
# --> 315 raise AttributeError("module {!r} has no attribute "
#     316                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'nunique'

# %%
oversample = SMOTE()
X, y = oversample.fit_resample(X, y)

# %%
train_ = train[train['target']==0]

# %%
train_ = train_.sample()

# %%
train = pd.concat([train, train_])

# %%
train['target'].value_counts()
# Out:
# 0    80
# 1    41
# 2    39
# Name: target, dtype: int64

# %%
test = pd.concat([X_test, y_test], axis=1)

# %%
test.to_csv('iris_test.csv', index=False)

# %%
train.to_csv('iris_train.csv', index=False)

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split

# %%
y = df['target'].to_frame() # define Y
X = df[df.columns.difference(['target'])] # define X
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42) # create train and test

# %%
# build model - Xgboost
params_xgb = None
xgb_mod = XGBClassifier(params = params_xgb, random_state=42,scale_pos_weight=100) # build classifier
xgb_mod = xgb_mod.fit(X_train,y_train.values.ravel()) 

# make prediction and check model accuracy 
y_pred = xgb_mod.predict(X_test)
# Out:
# [16:00:24] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-11.0-arm64-3.8/xgboost/src/learner.cc:627:
# Parameters: { "scale_pos_weight" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.

# %%
ExplainerDashboard(explainer, mode='jupyterlab').run()
# Out:
# Building ExplainerDashboard..
# ...
# Generating layout...
# Calculating dependencies...
# Reminder: you can store the explainer (including calculated dependencies) with explainer.dump('explainer.joblib') and reload with e.g. ClassifierExplainer.from_file('explainer.joblib')
# Registering callbacks...
# Starting ExplainerDashboard inline (terminate it with ExplainerDashboard.terminate(8050))

# %%
import pathlib
import os

_LOG_DIR = pathlib.Path(os.path.join('../outputs'))

if not _LOG_DIR.exists():
    _LOG_DIR.mkdir()

# %%
_LOG_DIR = pathlib.Path(os.path.join('../outputs/xgb'))

if not _LOG_DIR.exists():
    _LOG_DIR.mkdir()

# %%
_LOG_DIR
# Out:
# PosixPath('../outputs/xgb')
